# %%
import os 
import requests
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
res = requests.get('https://google.com')

# %%
#  'json',
#  'links',
#  'next',
#  'ok',
#  'raise_for_status',
#  'raw',
#  'reason',
#  'request',
#  'status_code',
#  'text',
#  'url'

res.text
# Out:
# '<!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" lang="tr"><head><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>Google</title><script nonce="1cEtuiRBROi1CnNf4PQENw">(function(){var _g={kEI:\'6m2fZ4_OG-fX5OUPlLW_oQw\',kEXPI:\'0,18167,3682156,1061,302126,236535,2872,2891,43028,46127,344796,212051,26408,8861,11813,11343,19568,5240755,766,8834933,7437932,182,16496047,4043709,25228681,65456,46668,10979,15165,8181,10492,38938,21675,6749,22594,1285,9139,4599,168,160,6225,1117,26873,5633,688,29854,1346,13703,48,15586,14520,3291,3491,33,4678,3908,455,17667,10673,24324,1501,3853,41,5595,8044,1,1720,5021,4105,301,52,1323,2779,908,2,7328,6540,913,5907,629,1521,758,3856,5773,4311,2063,263,1310,738,4381,3586,767,7531,2662,911,834,3,2,1920,710,339,1633,1,4728,955,4488,368,2893,41,2,416,1845,686,35,2094,165,6,761,394,714,1403,365,1275,55,561,463,1,137,690,1,
# ...

# %%
domain = 'facebook.com'
url = f'https://api.domainsdb.info/v1/domains/search?domain={domain}'

res = requests.get(url)
res
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 4
#       1 domain = 'facebook.com'
#       2 url = f'https://api.domainsdb.info/v1/domains/search?domain={domain}'
# ----> 4 res = requests.get(url)
#       5 res
#
# File ~/Desktop/Code/venv/lib/python3.13/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/Desktop/Code/venv/lib/python3.13/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
# ...

# %%
domains = res.json()
[d['domain'] for d in domains['domains']]

# %%
res = requests.get('https://api.ipify.org?format=json')
ip = res.json()['ip']

# %%
res = requests.get(f'https://ipinfo.io/{ip}/geo')

# %%
# post 

url = 'https://csclub.uwaterloo.ca/~phthakka/1pt-express/addURL'

params = {
    'long': 'https://google.com',
    'short': 'romashka'
}

res = requests.post(url, params=params)
res
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 10
#       3 url = 'https://csclub.uwaterloo.ca/~phthakka/1pt-express/addURL'
#       5 params = {
#       6     'long': 'https://google.com',
#       7     'short': 'romashka'
#       8 }
# ---> 10 res = requests.post(url, params=params)
#      11 res
#
# NameError: name 'requests' is not defined

# %%
res.json()

# %%
# Auth

func = 'TIME_SERIES_DAILY'
symbol = 'TSLA'
api_key = os.getenv('api_key')

url = f'https://www.alphavantage.co/query?function={func}&symbol={symbol}&apikey={api_key}'

r = requests.get(url)

data = r.json()

data
# Out:
# {'Meta Data': {'1. Information': 'Daily Prices (open, high, low, close) and Volumes',
#   '2. Symbol': 'TSLA',
#   '3. Last Refreshed': '2025-01-31',
#   '4. Output Size': 'Compact',
#   '5. Time Zone': 'US/Eastern'},
#  'Time Series (Daily)': {'2025-01-31': {'1. open': '401.5300',
#    '2. high': '419.9900',
#    '3. low': '401.3400',
#    '4. close': '404.6000',
#    '5. volume': '83568219'},
#   '2025-01-30': {'1. open': '410.7800',
#    '2. high': '412.5000',
#    '3. low': '384.4100',
#    '4. close': '400.2800',
#    '5. volume': '98092879'},
#   '2025-01-29': {'1. open': '395.2100',
#    '2. high': '398.5899',
#    '3. low': '384.4800',
#    '4. close': '389.1000',
#    '5. volume': '68033648'},
#   '2025-01-28': {'1. open': '396.9100',
#    '2. high': '400.5900',
#    '3. low': '386.5000',
#    '4. close': '398.0900',
#    '5. volume': '48910676'},
#   '2025-01-27': {'1. open': '394.8000',
#    '2. high': '406.6900',
#    '3. low': '389.0000',
#    '4. close': '397.1500',
# ...

# %%
import os

dict(os.environ) #возвращает словарь ключей-переменных окружения

os.getenv('EDITOR') #возвращает значение конкретного ключа из окружения
# Out:
# 'nano'

# %%
# простой способ создать переменную окружения
# но этот способ плох, потому что после перезагрузки ПК - переменная исчезнет из памяти
os.environ['FOO'] = '1'

# %%
os.environ['FOO']
# Out:
# '1'

# %%
#до установки -dotenv и импорта, мы сделали файл .env
# мы поместили в эвн апи ключ
from dotenv import load_dotenv

load_dotenv() 
#ищет файл .env в папке, где находится файл
# добавляет ключи из файла в текущее окружение
# Out:
# True

# %%
os.getenv('api_key')
# Out:
# 'hello'
